# %%
import pymonntorch as pmt
import torch
from matplotlib import pyplot as plt

import model as mdl
import syn
import dandrit as dnd
import current as cnt
import activity as act
from getDevice import get_device
from dt import TimeResolution
from plot import plot

# %%
from part4 import simulate_three_neuron_group,LIF,AELIF

# %%
simulate_three_neuron_group(
    current=cnt.UniformSingleCurrent(
        value=6.4, step=0.1, initial_current=100, noise_range=0.05
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=6, p=6, tau=1, variation=40),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-5, p=40, tau=1, variation=30),
    model_inh=LIF(tau_m=3, R=30),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current=cnt.UniformSingleCurrent(
        value=6.4, step=0.1, initial_current=100, noise_range=0.05
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=4, p=6, tau=1, variation=40),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-1, p=40, tau=3, variation=30),
    model_inh=LIF(tau_m=3, R=30),
    model_ex=LIF(tau_m=24,R=1.7),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current=cnt.UniformSingleCurrent(
        value=6.4, step=0.1, initial_current=100, noise_range=0.05
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=10, p=100, tau=1, variation=40),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-8, p=40, tau=3, variation=30),
    model_inh=LIF(tau_m=3, R=30),
    model_ex=LIF(tau_m=24,R=1.7),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current=cnt.UniformSingleCurrent(
        value=6.4, step=0.1, initial_current=100, noise_range=0.05
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=7, p=100, tau=1, variation=40),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=100, tau=1, variation=70),
    model_inh=LIF(tau_m=3, R=30),
    model_ex=LIF(tau_m=24,R=1.7),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current=cnt.UniformSingleCurrent(
        value=6.4, step=0.1, initial_current=100, noise_range=0.05
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=4, p=100, tau=1, variation=40),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=100, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-0.4, p=40, tau=1, variation=30),
    model_inh=LIF(tau_m=3, R=30),
    model_ex=LIF(tau_m=24,R=1.7),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current=cnt.UniformSingleCurrent(
        value=6.4, step=0.1, initial_current=100, noise_range=0.05
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=4, p=2, tau=3, variation=40),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=100, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-1, p=100, tau=3, variation=30),
    model_inh=LIF(tau_m=3, R=30),
    model_ex=LIF(tau_m=24,R=1.7),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.05
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=4, p=2, tau=1, variation=40),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=5, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-1, p=100, tau=1, variation=30),
    model_inh=LIF(tau_m=3, R=30),
    model_ex=LIF(tau_m=24,R=1.7),
    iteration=100,
    diff_current=0.01,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.05,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.05,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=1, variation=40),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=60, tau=1, variation=70),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.05,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.05,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivityFix(j0=9, connection_number=48, tau=1, variation=40),
    syn_model_ex_inh=syn.RandomConnectivityFix(j0=8, connection_number=8, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivityFix(j0=-7, connection_number=120, tau=1, variation=70),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.05,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.05,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=1, variation=40),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=60, tau=1, variation=70),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    n_size=200,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.05,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.05,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivityFix(j0=9, connection_number=48, tau=1, variation=40),
    syn_model_ex_inh=syn.RandomConnectivityFix(j0=8, connection_number=8, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivityFix(j0=-7, connection_number=120, tau=1, variation=70),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    n_size=200,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.05,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.05,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=1, variation=100),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=10, tau=1, variation=70),
    model_inh=LIF(tau_m=3, R=80),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.05
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=5, variation=40),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=60, tau=1, variation=70),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.01,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.05,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.05,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=1, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=60, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.05,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.05,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=5, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=60, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.05,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.05,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=5, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=10, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.1,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.1,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=5, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=10, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.1,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.1,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=1, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=10, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.1,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.1,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=1, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=10, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=22),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.1,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.1,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=1, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=10, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=6),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.1,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.1,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=1, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=10, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=70),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.1,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.1,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=1, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-25, p=10, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=20),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.1,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.1,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=1, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=50, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-25, p=10, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=20),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.1,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.1,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=1, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-25, p=50, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=20),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.1,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.1,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=1, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=10, tau=1, variation=60),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=22),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.1,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.1,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=1, variation=80),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=80),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=10, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=22),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.05,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.05,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=40, p=6, tau=1, variation=40),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=60, tau=1, variation=70),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.05,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.05,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=40, p=6, tau=1, variation=40),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=60, tau=1, variation=70),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=20),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=7.3, step=0.1, initial_current=100, noise_range=0.05,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.05,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=2, tau=1, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-9, p=60, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=90),
    model_ex=LIF(tau_m=30),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=7.2, step=0.1, initial_current=100, noise_range=0.05,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.05,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=2, tau=1, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-9, p=30, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=1000),
    model_ex=LIF(tau_m=30),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=7.1, step=0.1, initial_current=100, noise_range=0.05,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.05,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=2, tau=1, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-9, p=30, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=1000),
    model_ex=LIF(tau_m=30),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=7.1, step=0.1, initial_current=100, noise_range=0.5,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.5,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=2, tau=1, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-9, p=30, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=1000),
    model_ex=LIF(tau_m=30),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=7.1, step=0.5, initial_current=100, noise_range=0.5,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.5, initial_current=100, noise_range=0.5,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=2, tau=1, variation=20),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=20),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-9, p=30, tau=1, variation=20),
    model_inh=LIF(tau_m=3, R=1000),
    model_ex=LIF(tau_m=30),
    iteration=100,
    diff_current=0.005,
    dt=1,
)

# %%
simulate_three_neuron_group(
    current_ex1=cnt.UniformSingleCurrent(
        value=8, step=0.1, initial_current=100, noise_range=0.05,t0=10,t1=30,c1=6.7,c0=6.4
    ),
    current_ex2=cnt.UniformSingleCurrent(
        value=7, step=0.1, initial_current=100, noise_range=0.05,t0=10,c1=6.4,c0=6.4 ,t1=30
    ),
    syn_model_ex_ex=syn.RandomConnectivity(j0=9, p=6, tau=1, variation=40),
    syn_model_ex_inh=syn.RandomConnectivity(j0=8, p=1, tau=1, variation=30),
    syn_model_inh_ex=syn.RandomConnectivity(j0=-7, p=60, tau=1, variation=70),
    model_inh=LIF(tau_m=3, R=70),
    model_ex=LIF(tau_m=30),
    iteration=100,
    diff_current=0.005,
    dt=1,
)
